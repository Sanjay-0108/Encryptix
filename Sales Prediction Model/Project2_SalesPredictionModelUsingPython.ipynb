# %% [markdown]
# # SALES PREDICTION USING PYTHON

# %% [markdown]
# ## Step 1: Reading and Understanding the Data
#
# 1. Importing data using the pandas library
# 2. Understanding the structure of the data

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd

# %%
advertising = pd.read_csv("C:/Users/sanja/OneDrive/Desktop/Projects/Encryptix-Projects/Sales Prediction Model/advertising.csv")
advertising.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# # Inspecting data

# %%
advertising.shape
# Out:
# (200, 4)

# %%
advertising.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
advertising.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# ## Step 2: Visualising the Data

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.pairplot(advertising, x_vars=['TV', 'Newspaper', 'Radio'], y_vars='Sales',size=4, aspect=1, kind='scatter')
plt.show()

# %%
sns.heatmap(advertising.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %% [markdown]
# The variable 'TV' appears to be most linked with 'Sales', as can be seen from the pairplot and the heatmap. So let's conduct a straightforward linear regression with "TV" as the feature variable.

# %% [markdown]
# ## Step 3: Performing Simple Linear Regression

# %%
X = advertising['TV']
y = advertising['Sales']

# %% [markdown]
# #### Train-Test Split
#
# 70-30 % split.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
X_train.head()
# Out:
# 74     213.4
# 3      151.5
# 185    205.0
# 26     142.9
# 90     134.3
# Name: TV, dtype: float64

# %%
y_train.head()
# Out:
# 74     17.0
# 3      16.5
# 185    22.6
# 26     15.0
# 90     14.0
# Name: Sales, dtype: float64

# %% [markdown]
# #### Building a Linear Model

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.2-cp311-cp311-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\sanja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from statsmodels) (1.26.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\sanja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from statsmodels) (1.11.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\sanja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from statsmodels) (2.1.2)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\sanja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from statsmodels) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sanja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sanja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\sanja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six in c:\users\sanja\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Downloading statsmodels-0.14.2-cp311-cp311-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.9 MB 1.1 MB/s eta 0:00:09
#    ---------------------------------------- 0.1/9.9 MB 1.1 MB/s eta 0:00:09
#    ---------------------------------------- 0.1/9.9 MB 1.1 MB/s eta 0:00:09
#     --------------------------------------- 0.1/9.9 MB 655.8 kB/s eta 0:00:15
#     --------------------------------------- 0.2/9.9 MB 1.0 MB/s eta 0:00:10
#     --------------------------------------- 0.2/9.9 MB 1.0 MB/s eta 0:00:10
#     --------------------------------------- 0.2/9.9 MB 1.0 MB/s eta 0:00:10
#    - -------------------------------------- 0.3/9.9 MB 759.5 kB/s eta 0:00:13
#    - -------------------------------------- 0.5/9.9 MB 1.1 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/9.9 MB 1.1 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/9.9 MB 1.1 MB/s eta 0:00:09
#    -- ------------------------------------- 0.7/9.9 MB 1.1 MB/s eta 0:00:09
#    --- ------------------------------------ 0.8/9.9 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/9.9 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/9.9 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/9.9 MB 1.2 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.1/9.9 MB 1.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.1/9.9 MB 1.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.1/9.9 MB 1.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.2/9.9 MB 1.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.4/9.9 MB 1.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.4/9.9 MB 1.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.4/9.9 MB 1.4 MB/s eta 0:00:07
#    ------ --------------------------------- 1.5/9.9 MB 1.3 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9
MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 9.5/9.9 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 9.5/9.9 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  9.8/9.9 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 1.5 MB/s eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ---------------------------------------- 0.0/233.9 kB ? eta -:--:--
#    ----------------------------- ---------- 174.1/233.9 kB 5.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 174.1/233.9 kB 5.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 174.1/233.9 kB 5.3 MB/s eta 0:00:01
#    -------------------------------------- - 225.3/233.9 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 233.9/233.9 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.6 statsmodels-0.14.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: C:\Users\sanja\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import statsmodels.api as sm

# %%
X_train_sm = sm.add_constant(X_train)
lr = sm.OLS(y_train, X_train_sm).fit()

# %%
lr.params
# Out:
# const    6.948683
# TV       0.054546
# dtype: float64

# %%
# Performing a summary operation lists out all the different parameters of the regression line fitted
print(lr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     611.2
# Date:                Mon, 01 Jul 2024   Prob (F-statistic):           1.52e-52
# Time:                        22:10:44   Log-Likelihood:                -321.12
# No. Observations:                 140   AIC:                             646.2
# Df Residuals:                     138   BIC:                             652.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.9487      0.385     18.068      0.000       6.188       7.709
# TV             0.0545      0.002     24.722      0.000       0.050       0.059
# ==============================================================================
# Omnibus:                        0.027   Durbin-Watson:                   2.196
# Prob(Omnibus):                  0.987   Jarque-Bera (JB):                0.150
# Skew:                          -0.006   Prob(JB):                        0.928
# Kurtosis:                       2.840   Cond. No.                         328.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# The values we are concerned with-
# 1. The coefficients and significance (p-values)
# 2. R-squared
# 3. F statistic and its significance

# %% [markdown]
# The coefficient for TV is 0.054, with a very low p value

# %% [markdown]
# R - squared is 0.816

# %% [markdown]
# F statistic has a very low p value (practically low)

# %%
plt.scatter(X_train, y_train, label='Training Data')
plt.plot(X_train, 6.948 + 0.054 * np.array(X_train), 'r', label='Fitted Line')

plt.title('Scatter Plot with Fitted Line')
plt.xlabel('X_train')
plt.ylabel('y_train')
plt.legend()

plt.show()

# %% [markdown]
# ## Step 4: Residual analysis

# %%
y_train_pred = lr.predict(X_train_sm)
res = (y_train - y_train_pred)

# %%
fig = plt.figure()

# Plot the distribution of residuals
sns.histplot(res, bins=15, kde=True)

# Add titles and labels
fig.suptitle('Error Terms', fontsize=15)
plt.xlabel('y_train - y_train_pred', fontsize=15)

# Show the plot
plt.show()

# %% [markdown]
# The residuals are following the normally distributed with a mean 0. All good!

# %% [markdown]
# #### Looking for patterns in the residuals

# %%
# Create a scatter plot
plt.scatter(X_train, res)

# Add titles and labels
plt.title('Residuals vs. Fitted Values')
plt.xlabel('Fitted Values (X_train)')
plt.ylabel('Residuals')

# Show the plot
plt.show()

# %% [markdown]
# ## Step 5: Predictions on the Test Set

# %%
X_test_sm = sm.add_constant(X_test)
y_pred = lr.predict(X_test_sm)

# %%
y_pred.head()
# Out:
# 126     7.374140
# 104    19.941482
# 99     14.323269
# 92     18.823294
# 111    20.132392
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# ##### Looking at the RMSE

# %%
#Returns the mean squared error; we'll take a square root
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 2.019296008966232

# %% [markdown]
# ###### Checking the R-squared on the test set

# %%
r_squared = r2_score(y_test, y_pred)
r_squared
# Out:
# 0.792103160124566

# %% [markdown]
# ##### Visualizing the fit on the test set

# %%
plt.scatter(X_test, y_test, label='Test Data')

plt.plot(X_test, 6.948 + 0.054 * X_test, 'r', label='Fitted Line')

plt.title('Scatter Plot with Fitted Line')
plt.xlabel('X_test')
plt.ylabel('y_test')
plt.legend()

plt.show()

# %% [markdown]
# ### Linear Regression using linear_model in sklearn

# %%
from sklearn.model_selection import train_test_split
X_train_lm, X_test_lm, y_train_lm, y_test_lm = train_test_split(X, y, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
X_train_lm.shape
# Out:
# (140,)

# %%
# Assuming X_train_lm and X_test_lm are pandas Series
X_train_lm = np.array(X_train_lm).reshape(-1, 1)
X_test_lm = np.array(X_test_lm).reshape(-1, 1)

# %%
print(X_train_lm.shape)
print(y_train_lm.shape)
print(X_test_lm.shape)
print(y_test_lm.shape)
# Out:
# (140, 1)
# (140,)
# (60, 1)
# (60,)

# %%
from sklearn.linear_model import LinearRegression

# Representing LinearRegression as lr(Creating LinearRegression Object)
lm = LinearRegression()

# Fit the model using lr.fit()
lm.fit(X_train_lm, y_train_lm)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
print(lm.coef_)
# Out:
# 6.948683200001357
# [0.05454575]

# %% [markdown]
# Same values of Y=mx+c we get now as we got earlier with OLS.

# %%
corrs = np.corrcoef(X_train, y_train)
print(corrs)
# Out:
# [[1.         0.90321277]
#  [0.90321277 1.        ]]

# %%
corrs[0,1] ** 2
# Out:
# 0.8157933136480386

# %% [markdown]
# While the true benefits of scaling will be apparent during future modules, at this juncture we can discuss if it has an impact on the model.
#
# We'll rebuild the model after scaling the predictor and see what changes.
#
# # Standard Scaling

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, test_size = 0.3, random_state = 100)

# %% [markdown]
# #### SciKit Learn has these scaling utilities handy

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
X_train_scaled = X_train.values.reshape(-1, 1)
y_train_scaled = y_train.values.reshape(-1, 1)

# %%
X_train_scaled.shape
# Out:
# (140, 1)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_scaled)
y_train_scaled = scaler.fit_transform(y_train_scaled)

# %%
print("Mean and sd for X_train_scaled:", np.mean(X_train_scaled), np.std(X_train_scaled))
print("Mean and sd for y_train_scaled:", np.mean(y_train_scaled), np.std(y_train_scaled))
# Out:
# Mean and sd for X_train_scaled: 2.5376526277146434e-17 0.9999999999999999
# Mean and sd for y_train_scaled: -2.5376526277146434e-16 1.0

# %%
X_train_scaled = sm.add_constant(X_train_scaled)

lr_scaled = sm.OLS(y_train_scaled, X_train_scaled).fit()

# %%
lr_scaled.params
# Out:
# array([-2.44596010e-16,  9.03212773e-01])

# %% [markdown]
# As you might notice, the value of the parameters have changed since we have changed the scale.

# %% [markdown]
# Let's look at the statistics of the model, to see if any other aspect of the model has changed.

# %%
print(lr_scaled.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     611.2
# Date:                Mon, 01 Jul 2024   Prob (F-statistic):           1.52e-52
# Time:                        22:11:02   Log-Likelihood:                -80.233
# No. Observations:                 140   AIC:                             164.5
# Df Residuals:                     138   BIC:                             170.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.446e-16      0.037  -6.69e-15      1.000      -0.072       0.072
# x1             0.9032      0.037     24.722      0.000       0.831       0.975
# ==============================================================================
# Omnibus:                        0.027   Durbin-Watson:                   2.196
# Prob(Omnibus):                  0.987   Jarque-Bera (JB):                0.150
# Skew:                          -0.006   Prob(JB):                        0.928
# Kurtosis:                       2.840   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
